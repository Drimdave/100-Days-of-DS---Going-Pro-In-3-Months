# %% [markdown]
# <br><br><right><h1 style="font-size:4em;color:#2467C0">DAY 10 - SHOOTING ANALYSIS USING THE SHOOTING DATASET</h1></right>
# <br>
# <table>
# <col width="550">
# <col width="450">
# <tr>
# This dataset contains information about the shootings that took place.

# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\seyi\Desktop\MY DATA SCIENCE WORKS, TUTORIAL AND JOURNEY\100 days of DS\Resources\Projects\Data Science Analysis\Dataset\shootings.csv")

# %%
df
# Out:
#         id                name        date   manner_of_death       armed  \
# 0        3          Tim Elliot  2015-01-02              shot         gun
# 1        4    Lewis Lee Lembke  2015-01-02              shot         gun
# 2        5  John Paul Quintero  2015-01-03  shot and Tasered     unarmed
# 3        8     Matthew Hoffman  2015-01-04              shot  toy weapon
# 4        9   Michael Rodriguez  2015-01-04              shot    nail gun
# ...    ...                 ...         ...               ...         ...
# 4890  5916     Rayshard Brooks  2020-06-12              shot       Taser
# 4891  5925      Caine Van Pelt  2020-06-12              shot         gun
# 4892  5918        Hannah Fizer  2020-06-13              shot     unarmed
# 4893  5921      William Slyter  2020-06-13              shot         gun
# 4894  5924      Nicholas Hirsh  2020-06-15              shot         gun
#
#        age gender      race           city state  signs_of_mental_illness  \
# ...

# %% [markdown]
# # Data Cleaning

# %%
df.isnull()
# Out:
#          id   name   date  manner_of_death  armed    age  gender   race  \
# 0     False  False  False            False  False  False   False  False
# 1     False  False  False            False  False  False   False  False
# 2     False  False  False            False  False  False   False  False
# 3     False  False  False            False  False  False   False  False
# 4     False  False  False            False  False  False   False  False
# ...     ...    ...    ...              ...    ...    ...     ...    ...
# 4890  False  False  False            False  False  False   False  False
# 4891  False  False  False            False  False  False   False  False
# 4892  False  False  False            False  False  False   False  False
# 4893  False  False  False            False  False  False   False  False
# 4894  False  False  False            False  False  False   False  False
#
#        city  state  signs_of_mental_illness  threat_level   flee  body_camera  \
# ...

# %%
df.isnull().sum()
# Out:
# id                         0
# name                       0
# date                       0
# manner_of_death            0
# armed                      0
# age                        0
# gender                     0
# race                       0
# city                       0
# state                      0
# signs_of_mental_illness    0
# threat_level               0
# flee                       0
# body_camera                0
# arms_category              0
# dtype: int64

# %% [markdown]
# # Covert the 'id' column to the 'case' and show the number of cases by states

# %%
tmp_df = df[['id','state']]
tmp_df = tmp_df.groupby('state', as_index=False).count()
tmp_df = tmp_df.rename(columns={'id':'case'})

# %%
tmp_df.head()
# Out:
#   state  case
# 0    AK    36
# 1    AL    95
# 2    AR    73
# 3    AZ   222
# 4    CA   701

# %% [markdown]
# # Show the value count of the gender

# %%
df['gender'].value_counts()
# Out:
# M    4673
# F     222
# Name: gender, dtype: int64

# %% [markdown]
# # Show the males only and the females only

# %%
# Males only 
df[df['gender'] == 'M']
# Out:
#         id                name        date   manner_of_death       armed  \
# 0        3          Tim Elliot  2015-01-02              shot         gun
# 1        4    Lewis Lee Lembke  2015-01-02              shot         gun
# 2        5  John Paul Quintero  2015-01-03  shot and Tasered     unarmed
# 3        8     Matthew Hoffman  2015-01-04              shot  toy weapon
# 4        9   Michael Rodriguez  2015-01-04              shot    nail gun
# ...    ...                 ...         ...               ...         ...
# 4889  5915      Michael Thomas  2020-06-11              shot     unknown
# 4890  5916     Rayshard Brooks  2020-06-12              shot       Taser
# 4891  5925      Caine Van Pelt  2020-06-12              shot         gun
# 4893  5921      William Slyter  2020-06-13              shot         gun
# 4894  5924      Nicholas Hirsh  2020-06-15              shot         gun
#
#        age gender      race           city state  signs_of_mental_illness  \
# ...

# %%
# Females only 
df[df['gender'] == 'F']
# Out:
#         id                   name        date   manner_of_death    armed  \
# 8       16          Autumn Steele  2015-01-06              shot  unarmed
# 51     100     Kristiana Coignard  2015-01-22  shot and Tasered    knife
# 59      20       Jessie Hernandez  2015-01-26              shot  unknown
# 63     111          Tiffany Terry  2015-01-27              shot    knife
# 79     118      Yuvette Henderson  2015-02-03              shot      gun
# ...    ...                    ...         ...               ...      ...
# 4809  5808      Sandra Lee Harmon  2020-05-05              shot      gun
# 4855  5875           Tracy Drowne  2020-05-26              shot      gun
# 4865  5844  Heba Momtaz Al-Azhari  2020-05-29              shot    knife
# 4878  5898          Mary Lawrence  2020-06-03              shot    knife
# 4892  5918           Hannah Fizer  2020-06-13              shot  unarmed
#
#        age gender      race            city state  signs_of_mental_illness  \
# ...

# %% [markdown]
# # Show the value count for the manner of deaths

# %%
df['manner_of_death'].value_counts()
# Out:
# shot                4647
# shot and Tasered     248
# Name: manner_of_death, dtype: int64

# %% [markdown]
# # Show the value count for the race

# %%
df['race'].value_counts()
# Out:
# White       2476
# Black       1298
# Hispanic     902
# Asian         93
# Native        78
# Other         48
# Name: race, dtype: int64

# %% [markdown]
# # Show the Arms category count

# %%
df['arms_category'].value_counts()
# Out:
# Guns                     2764
# Sharp objects             818
# Unknown                   418
# Unarmed                   348
# Other unusual objects     192
# Blunt instruments         122
# Vehicles                  121
# Multiple                   54
# Piercing objects           29
# Electrical devices         24
# Explosives                  4
# Hand tools                  1
# Name: arms_category, dtype: int64

# %% [markdown]
# # Combine race and other attributes (signs of mental illness, flee, etc.)

# %%
df['signs_of_mental_illness'].value_counts()
# Out:
# False    3792
# True     1103
# Name: signs_of_mental_illness, dtype: int64

# %%
df[['race', 'signs_of_mental_illness']].groupby(['race']).head()
# Out:
#          race  signs_of_mental_illness
# 0       Asian                     True
# 1       White                    False
# 2    Hispanic                    False
# 3       White                     True
# 4    Hispanic                    False
# 5       White                    False
# 6    Hispanic                    False
# 7       White                    False
# 8       White                    False
# 9       Black                    False
# 11      Black                    False
# 12      Black                     True
# 14      Black                    False
# 17      Black                    False
# 20   Hispanic                    False
# 22   Hispanic                    False
# 38      Other                    False
# 64     Native                    False
# 69      Asian                     True
# 152     Asian                    False
# 159     Asian                    False
# 212    Native                    False
# 263     Asian                     True
# ...

# %%
df['flee'].value_counts()
# Out:
# Not fleeing    3073
# Car             820
# Foot            642
# Other           360
# Name: flee, dtype: int64

# %%
df[['race', 'flee']].groupby(['race']).head()
# Out:
#          race         flee
# 0       Asian  Not fleeing
# 1       White  Not fleeing
# 2    Hispanic  Not fleeing
# 3       White  Not fleeing
# 4    Hispanic  Not fleeing
# 5       White  Not fleeing
# 6    Hispanic          Car
# 7       White  Not fleeing
# 8       White  Not fleeing
# 9       Black  Not fleeing
# 11      Black  Not fleeing
# 12      Black  Not fleeing
# 14      Black         Foot
# 17      Black  Not fleeing
# 20   Hispanic  Not fleeing
# 22   Hispanic  Not fleeing
# 38      Other  Not fleeing
# 64     Native  Not fleeing
# 69      Asian  Not fleeing
# 152     Asian  Not fleeing
# 159     Asian  Not fleeing
# 212    Native          Car
# 263     Asian  Not fleeing
# 292    Native         Foot
# 324     Other  Not fleeing
# 329     Other  Not fleeing
# 349     Other  Not fleeing
# 383     Other  Not fleeing
# 431    Native  Not fleeing
# 500    Native         Foot

# %%
df['body_camera'].value_counts()
# Out:
# False    4317
# True      578
# Name: body_camera, dtype: int64

# %%
df[['race', 'body_camera']].groupby(['race']).head()
# Out:
#          race  body_camera
# 0       Asian        False
# 1       White        False
# 2    Hispanic        False
# 3       White        False
# 4    Hispanic        False
# 5       White        False
# 6    Hispanic        False
# 7       White        False
# 8       White         True
# 9       Black        False
# 11      Black        False
# 12      Black        False
# 14      Black         True
# 17      Black        False
# 20   Hispanic        False
# 22   Hispanic        False
# 38      Other        False
# 64     Native        False
# 69      Asian        False
# 152     Asian        False
# 159     Asian        False
# 212    Native        False
# 263     Asian        False
# 292    Native        False
# 324     Other         True
# 329     Other        False
# 349     Other        False
# 383     Other        False
# 431    Native        False
# 500    Native        False

# %% [markdown]
# # Create a 'year', 'month', 'day' and 'day of week' column

# %%
df['new_date'] = pd.to_datetime(df['date'])
df['year'] = df['new_date'].dt.year
df['month'] = df['new_date'].dt.month
df['day'] = df['new_date'].dt.day
df['day_of_week'] = df['new_date'].dt.day_name()

# %%
df.head()
# Out:
#    id                name        date   manner_of_death       armed   age  \
# 0   3          Tim Elliot  2015-01-02              shot         gun  53.0
# 1   4    Lewis Lee Lembke  2015-01-02              shot         gun  47.0
# 2   5  John Paul Quintero  2015-01-03  shot and Tasered     unarmed  23.0
# 3   8     Matthew Hoffman  2015-01-04              shot  toy weapon  32.0
# 4   9   Michael Rodriguez  2015-01-04              shot    nail gun  39.0
#
#   gender      race           city state  signs_of_mental_illness threat_level  \
# 0      M     Asian        Shelton    WA                     True       attack
# 1      M     White          Aloha    OR                    False       attack
# 2      M  Hispanic        Wichita    KS                    False        other
# 3      M     White  San Francisco    CA                     True       attack
# 4      M  Hispanic          Evans    CO                    False       attack
#
# ...

# %% [markdown]
# # Cases that happend in 2020

# %%
df[df['year'] == 2020]
# Out:
#         id                            name        date   manner_of_death  \
# 4521  5344               Derrick A. Elseth  2020-01-01              shot
# 4522  5403  Gerardo Antonio Conchas-Bustas  2020-01-01              shot
# 4523  5342              Gabriel Strickland  2020-01-01  shot and Tasered
# 4524  5339            Jeffery Dale Millsap  2020-01-02              shot
# 4525  5349            Jamari Daiwon Tarver  2020-01-02              shot
# ...    ...                             ...         ...               ...
# 4890  5916                 Rayshard Brooks  2020-06-12              shot
# 4891  5925                  Caine Van Pelt  2020-06-12              shot
# 4892  5918                    Hannah Fizer  2020-06-13              shot
# 4893  5921                  William Slyter  2020-06-13              shot
# 4894  5924                  Nicholas Hirsh  2020-06-15              shot
#
#            armed   age gender   race             city state  \
# ...

# %% [markdown]
# # Show the cases that happend on Friday

# %%
df[df['day_of_week'] == 'Friday']
# Out:
#         id                 name        date manner_of_death    armed   age  \
# 0        3           Tim Elliot  2015-01-02            shot      gun  53.0
# 1        4     Lewis Lee Lembke  2015-01-02            shot      gun  47.0
# 19      38        Jimmy Foreman  2015-01-09            shot      gun  71.0
# 20     325        Andy Martinez  2015-01-09            shot      gun  33.0
# 37      67           Scott Hall  2015-01-16            shot      gun  41.0
# ...    ...                  ...         ...             ...      ...   ...
# 4868  5850  Momodou Lamin Sisay  2020-05-29            shot      gun  39.0
# 4869  5879      Jarvis Sullivan  2020-05-29            shot  vehicle  44.0
# 4882  5903     Benjamin Ballard  2020-06-05            shot      gun  42.0
# 4890  5916      Rayshard Brooks  2020-06-12            shot    Taser  27.0
# 4891  5925       Caine Van Pelt  2020-06-12            shot      gun  23.0
#
#      gender      race         city state  signs_of_mental_illness  \
# ...

# %% [markdown]
# # Cases that happend in 2015 on Wednesday

# %%
df[(df.year == 2015) & (df.day_of_week == 'Wednesday')]
# Out:
#        id                              name        date manner_of_death  \
# 11     21                         Ron Sneed  2015-01-07            shot
# 12     22    Hashim Hanif Ibn Abdul-Rasheed  2015-01-07            shot
# 13     25            Nicholas Ryan Brickman  2015-01-07            shot
# 14     27  Omarr Julian Maximillian Jackson  2015-01-07            shot
# 26     49                     Marcus Golden  2015-01-14            shot
# ..    ...                               ...         ...             ...
# 890  1054                  Florencio Lucero  2015-12-02            shot
# 904  1069                Christopher Higdon  2015-12-09            shot
# 928  1097                Bryant Neil Duncan  2015-12-16            shot
# 948  1118                    Kevin Matthews  2015-12-23            shot
# 963  1135                        Fred Perez  2015-12-30            shot
#
#        armed        age gender      race         city state  \
# ...

# %% [markdown]
# # Show the cases that happend at ages 30 and above

# %%
df[df['age'] > 30]
# Out:
#         id               name        date manner_of_death       armed   age  \
# 0        3         Tim Elliot  2015-01-02            shot         gun  53.0
# 1        4   Lewis Lee Lembke  2015-01-02            shot         gun  47.0
# 3        8    Matthew Hoffman  2015-01-04            shot  toy weapon  32.0
# 4        9  Michael Rodriguez  2015-01-04            shot    nail gun  39.0
# 7       15      Brock Nichols  2015-01-06            shot         gun  35.0
# ...    ...                ...         ...             ...         ...   ...
# 4882  5903   Benjamin Ballard  2020-06-05            shot         gun  42.0
# 4885  5908       Jarrid Hurst  2020-06-07            shot       knife  35.0
# 4886  5911       Lewis Ruffin  2020-06-09            shot         gun  38.0
# 4889  5915     Michael Thomas  2020-06-11            shot     unknown  62.0
# 4894  5924     Nicholas Hirsh  2020-06-15            shot         gun  31.0
#
# ...

# %% [markdown]
# # Show those who had body cam and who didn't

# %%
# Had body camera on them
df[df['body_camera'] == True]
# Out:
#         id                              name        date   manner_of_death  \
# 8       16                     Autumn Steele  2015-01-06              shot
# 14      27  Omarr Julian Maximillian Jackson  2015-01-07              shot
# 16      32               James Dudley Barker  2015-01-08              shot
# 18      37                      Thomas Hamby  2015-01-08              shot
# 24      46               John Edward O'Keefe  2015-01-13              shot
# ...    ...                               ...         ...               ...
# 4853  5857              Jason Jesse Gallegos  2020-05-26              shot
# 4861  5846                     Modesto Reyes  2020-05-27  shot and Tasered
# 4873  5842                      David McAtee  2020-06-01              shot
# 4877  5897                    Tyquarn Graves  2020-06-02              shot
# 4890  5916                   Rayshard Brooks  2020-06-12              shot
#
#         armed   age gender   race              city state  \
# ...

# %%
# Did not have body camera on them
df[df['body_camera'] == False]
# Out:
#         id                name        date   manner_of_death       armed  \
# 0        3          Tim Elliot  2015-01-02              shot         gun
# 1        4    Lewis Lee Lembke  2015-01-02              shot         gun
# 2        5  John Paul Quintero  2015-01-03  shot and Tasered     unarmed
# 3        8     Matthew Hoffman  2015-01-04              shot  toy weapon
# 4        9   Michael Rodriguez  2015-01-04              shot    nail gun
# ...    ...                 ...         ...               ...         ...
# 4889  5915      Michael Thomas  2020-06-11              shot     unknown
# 4891  5925      Caine Van Pelt  2020-06-12              shot         gun
# 4892  5918        Hannah Fizer  2020-06-13              shot     unarmed
# 4893  5921      William Slyter  2020-06-13              shot         gun
# 4894  5924      Nicholas Hirsh  2020-06-15              shot         gun
#
#        age gender      race           city state  signs_of_mental_illness  \
# ...
